# %% [markdown]
# <a href="https://colab.research.google.com/github/ruthikka19/FDE-lab-sec-1/blob/main/Ruthikka_250200407_cars.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Graded Lab week 2**

# %% [markdown]
# # **35/100 Marks: used_cars Scrape**

# %% [markdown]
# [link text](https://www.cardekho.com/used-cars+in+chennai/page-2)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **column names you have to extracted from the given data:**

# %% [markdown]
# ```
# | Proposed Column Name | Description                            | Sample Extracted Data (Card 1) | Sample Extracted Data (Card 2) |
# | -------------------- | -------------------------------------- | ------------------------------ | ------------------------------ |
# | `car_make`           | Manufacturer brand                     | Skoda                          | Maruti Suzuki                  |
# | `car_model`          | Model name                             | Kushaq                         | Baleno                         |
# | `car_name`           | Full car title                         | Skoda Kushaq                   | Maruti Suzuki Baleno           |
# | `manufacturing_year` | Year of manufacture                    | 2021                           | 2018                           |
# | `price`              | Listed selling price                   | ₹8.25L                         | ₹6.20L                         |
# | `kilometers_driven`  | Odometer reading                       | 96,984 kms                     | 30,000 kms                     |
# | `transmission`       | Gearbox type                           | Automatic                      | Automatic                      |
# | `fuel_type`          | Engine fuel source                     | Petrol                         | Petrol                         |
# | `location`           | Specific area/neighborhood             | Nungambakkam                   | Anna Nagar                     |
# | `city`               | City location                          | Chennai                        | Chennai                        |
# | `image_url`          | Main car image link from `<img>` `src` | `https://...`                  | `https://...`                  |
#
# ```

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
page_url="https://www.cardekho.com/used-cars+in+chennai/page-2"

# %%
# 3. Send HTTP request
response = requests.get(page_url)
print(f"Status Code: {response.status_code}")
# Out:
# Status Code: 403

# %%
response.content
# Out:
# b'<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">\n<HTML><HEAD><META HTTP-EQUIV="Content-Type" CONTENT="text/html; charset=iso-8859-1">\n<TITLE>ERROR: The request could not be satisfied</TITLE>\n</HEAD><BODY>\n<H1>403 ERROR</H1>\n<H2>The request could not be satisfied.</H2>\n<HR noshade size="1px">\nRequest blocked.\nWe can\'t connect to the server for this app or website at this time. There might be too much traffic or a configuration error. Try again later, or contact the app or website owner.\n<BR clear="all">\nIf you provide content to customers through CloudFront, you can find steps to troubleshoot and help prevent this error by reviewing the CloudFront documentation.\n<BR clear="all">\n<HR noshade size="1px">\n<PRE>\nGenerated by cloudfront (CloudFront)\nRequest ID: sLDUlZ03MpsQR6Dp0JqaIlHz0DXAXreO95EM1RFA3Em4vDPv968EaA==\n</PRE>\n<ADDRESS>\n</ADDRESS>\n</BODY></HTML>'

# %%
# 1. Send request
response = requests.get(page_url,headers={"User-Agent": "Mozilla/5.0"})

print("Status Code:", response.status_code)
# Out:
# Status Code: 200

# %%
print("Status Code:", response.status_code)
print("Page Length:", len(response.text))
# Out:
# Status Code: 200
# Page Length: 702919

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" translate="no">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="notranslate" name="google"/>
#   <title>
#    Used Cars in Chennai, 1381 Second Hand Cars in Chennai - CarDekho
#   </title>
#   <meta content="Explore 1381+ Used Cars in Chennai. Buy second-hand cars in Chennai starting from ₹95,000. Choose from pre-owned cars like City, Creta, i20 and KWID, available with 1-year warranty, RC transfer and easy finance." name="description"/>
#   <link crossorigin="anonymous" href="https://staticcont.cardekho.com" rel="preconnect dns-prefetch"/>
#   <link crossorigin="anonymous" href="https://stimg.cardekho.com" rel="preconnect dns-prefetch"/>
#   <link crossorigin="anonymous" href="https://connect.facebook.net" rel="preconnect dns-prefetch"/>
#   <link crossorigin="anonymous" href="https://www.googletagmanager.com" rel="preconnect dns-prefetch"/>
# ...

# %%
print(soup.title)
# Out:
# <title>Used Cars in Chennai, 1381 Second Hand Cars in Chennai - CarDekho | Page 2 of 69</title>

# %%
cars=soup.find_all('div',class_="NewUcExCard posR moreHeight")

# %%
len(cars)
# Out:
# 20

# %%
car=cars[0]
car
# Out:
# <div class="NewUcExCard posR moreHeight"><div class="image_container posR"><div class="imagebox hover extraSpaceonSlide"><div class="posR singleImage"><img alt="Second-hand 2021 Skoda Kushaq 1.0 TSI Style AT BSVI for sale in Chennai" class="hover 3" decoding="async" fetchpriority="high" height="154px" loading="eager" src="https://images10.gaadi.com/usedcar_image/5509989/original/processed_bb42034634892043c4ffd718b6c0fbe9.jpeg?imwidth=640" title="Skoda Kushaq 1.0 TSI Style AT BSVI" width="254px"/></div></div><div class="whiteIconsOnTop partnerIcon"><div class="sellertype"><img alt="animated icon" decoding="async" fetchpriority="high" loading="eager" src="https://stimg.cardekho.com/usedcar/images/uc/partnericon.svg"/><span>Partner</span></div><div class="insideCircleSlot">Featured</div></div><div class="bookmarkIcon"><div class="shortlist NewUcrShortList" id="shortlistHeartIcon"><img alt="Search" decoding="async" fetchpriority="high" height="30px" loading="eager" src="https://stimg.car
# ...

# %%
car.h3
# Out:
# <h3 class="title"><a href="/used-car-details/used-Skoda-kushaq-10-tsi-style-at-bsvi-cars-Chennai_0e94c37c-ae31-44a6-8ec1-43c4f0d4cc19.htm?adId=32732&amp;adType=41" rel="noreferrer" target="_blank" title="2021 Skoda Kushaq 1.0 TSI Style AT BSVI">Skoda Kushaq<!-- --> <span>2021</span></a></h3>

# %%
car.a
# Out:
# <a href="/used-car-details/used-Skoda-kushaq-10-tsi-style-at-bsvi-cars-Chennai_0e94c37c-ae31-44a6-8ec1-43c4f0d4cc19.htm?adId=32732&amp;adType=41" rel="noreferrer" target="_blank" title="2021 Skoda Kushaq 1.0 TSI Style AT BSVI">Skoda Kushaq<!-- --> <span>2021</span></a>

# %%
car.a['title']
# Out:
# '2021 Skoda Kushaq 1.0 TSI Style AT BSVI'
