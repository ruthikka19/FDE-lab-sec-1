# %% [markdown]
# <a href="https://colab.research.google.com/github/ruthikka19/FDE-lab-sec-1/blob/main/Ruthikka_250200407_fde_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #

# %% [markdown]
# # **Graded Lab week 2**

# %% [markdown]
# # **35/100 Marks: mobiles Scrape**

# %% [markdown]
# [link text](https://www.flipkart.com/q/5g-mobiles-under-30000?page=2)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **column names you have to extracted from the given data:**

# %% [markdown]
# ```
# | Proposed Column Name  | Description                                  | Extracted Sample Data                            |
# | --------------------- | -------------------------------------------- | ------------------------------------------------ |
# | `product_title`       | Full product name                            | MOTOROLA G77 Power (PANTONE Fuchsia Red, 128 GB) |
# | `brand`               | Brand name                                   | MOTOROLA                                         |
# | `color`               | Color variant                                | PANTONE Fuchsia Red                              |
# | `storage`             | Internal storage capacity                    | 128 GB                                           |
# | `ram`                 | RAM capacity                                 | 8 GB RAM                                         |
# | `expandable_memory`   | Maximum expandable storage                   | Expandable Upto 1 TB                             |
# | `discounted_price`    | Current selling price                        | ₹26,999                                          |
# | `original_price`      | Maximum Retail Price (MRP)                   | ₹44,999                                          |
# | `discount_percentage` | Discount applied                             | 40% off                                          |
# | `rating_stars`        | Average star rating                          | 4.0                                              |
# | `total_ratings`       | Total number of ratings                      | 57                                               |
# | `total_reviews`       | Total number of user reviews                 | 8                                                |
# | `display_size`        | Screen size & resolution details             | 17.07 cm (6.72 inch) Full HD+ Display            |
# | `rear_camera`         | Rear camera specs                            | 50MP + 8MP                                       |
# | `front_camera`        | Front/Selfie camera specs                    | 32MP Front Camera                                |
# | `battery_capacity`    | Battery size                                 | 7000 mAh Battery                                 |
# | `processor`           | CPU/Chipset                                  | Dimensity 6400 Processor                         |
# | `warranty`            | Warranty terms                               | 1 Year on Handset and 6 Months on Accessories    |                                            |
# | `image_url`           | Product thumbnail image URL from `<img src>` | https://...                                      |
#
# ```

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
page_url="https://www.flipkart.com/q/5g-mobiles-under-30000"

# %%
# 3. Send HTTP request
response = requests.get(page_url)
print(f"Status Code: {response.status_code}")
# Out:
# Status Code: 200

# %%
response.content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/bundle.aa1465.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/bundle.fbaef9.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="ap
# ...

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
print("Status Code:", response.status_code)
print("Page Length:", len(response.text))
# Out:
# Status Code: 200
# Page Length: 162496

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim2.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/bundle.aa1465.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/bundle.fbaef9.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Flipkart.com" name="og_site_name" property="og:site_name"/>
# ...

# %%
print(soup.title)
# Out:
# <title>5g mobiles under 30000 Online in India | Flipkart | 17-Aug-26</title>

# %%
page_url='https://www.flipkart.com/q/5g-mobiles-under-30000'

# %%
# 1. Send request
response = requests.get(page_url,headers={"User-Agent": "Mozilla/5.0"})

print("Status Code:", response.status_code)
# Out:
# Status Code: 529

# %%
print("Status Code:", response.status_code)
print("Page Length:", len(response.text))
# Out:
# Status Code: 529
# Page Length: 18

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim2.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/bundle.aa1465.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/bundle.fbaef9.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Flipkart.com" name="og_site_name" property="og:site_name"/>
# ...

# %%
print(soup.title)
# Out:
# <title>5g mobiles under 30000 Online in India | Flipkart | 17-Aug-26</title>

# %%
soup.find_all('p')
# Out:
# [<p>With the advancement of fifth-generation mobile network technology, more and more people are showing an interest in availing <a href="/5g-mobile-phones-store">5G phones</a>. Interestingly, there are a number of 5G mobiles under 30000 that offer optimal performance to cater to your diverse needs. The faster network connectivity supported by these phones ensures that you can enjoy a seamless movie or series streaming experience. Moreover, the processors from Qualcomm Snapdragon, Mediatek Dimensity, Google Tensor, etc., offer a glitch-free and immersive online gaming experience. These processors also come in handy for your professional endeavours, as you can multitask and run multiple apps on your smartphone without any latency. The 5G connectivity further enables you to conduct online seminars or video calls without any hassle. These phones also have batteries with up to 6000 mAh capacity. As a result, you do not have to worry about the phone running out of charge with regular use.
# ...

# %%
soup.find_all('h3')
# Out:
# [<h3>Reasons to Buy 5G Mobiles Under 30000</h3>]

# %%
soup.find_all('div')
# Out:
# [<div id="container"><div><div class="CgvN2_"><div class="nzadEb"><div class="VQf4aO"></div><div class="nS94SX"><div class="Bfhncs"><div class="gWHkja"><a href="/"><img alt="Flipkart" class="TVd0Ah" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/flipkart-plus_8d85f4.png" title="Flipkart" width="75"/></a><a class="p8iyLE" href="/plus">Explore<!-- --> <span class="stfyUS">Plus</span><img src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/plus_aef861.png" width="10"/></a></div></div><div class="yZCQWU"><form action="/search" class="rcHWnF header-form-search" method="GET"><div class="col-12-12 kdPmDK"><div class="DjsUBA"><input autocomplete="off" class="Vy9RSP" name="q" placeholder="Search for products, brands and more" title="Search for products, brands and more" type="text" value=""/></div><button class="bJtikv" type="submit"><svg class="" height="20" viewbox="0 0 17 18" width="20" xmlns="http://www.w3.org/2000/svg"><g fill="#2874F1" fill-rul
# ...

# %%
mobiles=soup.find_all('div',class_="jIjQ8S")

# %%
len(mobiles)
# Out:
# 24

# %%
mobile=mobiles[0]

# %%
mobile
# Out:
# <div class="jIjQ8S"><a class="k7wcnx" href="/vivo-t5x-5g-cyber-green-128-gb/p/itm7da8aa253e72b?pid=MOBHH69NM5ERRNFT&amp;lid=LSTMOBHH69NM5ERRNFTB1RHB5&amp;marketplace=FLIPKART&amp;store=tyy%2F4io&amp;spotlightTagId=default_BestsellerId_tyy%2F4io&amp;srno=b_1_1&amp;otracker=browse&amp;fm=organic&amp;iid=b308d275-a7b6-462f-856d-c92bdc8fb67a.MOBHH69NM5ERRNFT.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=dcgmbjwitc0000001786988621903&amp;ov_redirect=true" rel="noopener noreferrer" target="_blank"><div></div><div class="T6hTMI"><div class="R7Cntx"><div><div class="lWX0_T" style="height:200px;width:200px"><img alt="vivo T5x 5G (Cyber Green, 128 GB)" class="UCc1lI" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/xif0q/mobile/f/i/v/-original-imahhhfvqhmf7fgg.jpeg?q=70"/></div></div></div><div class="b0bTm6"><div class="FJ7IAS"><span class="ZhHnSZ"><label class="BMOCJ3"><input class="UXWKAE" readonly="" type="checkbox"/><div class="ybaCDx"></div></label></span><label class="fU6cH
# ...

# %%
mobile.find('div',class_="RG5Slk").text
# Out:
# <div class="RG5Slk">vivo T5x 5G (Cyber Green, 128 GB)</div>

# %%
mobile.find('div',class_="RG5Slk").text
# Out:
# 'vivo T5x 5G (Cyber Green, 128 GB)'

# %%
mobile.find('div',class_="RG5Slk")['class']
# Out:
# ['RG5Slk']

# %%
mobile.find('li',class_="DTBslk")
# Out:
# <li class="DTBslk">8 GB RAM | 128 GB ROM</li>

# %%
mobile.find('li',class_="DTBslk").text
# Out:
# '8 GB RAM | 128 GB ROM'

# %%
mobile.find_all('li',class_="DTBslk")
# Out:
# [<li class="DTBslk">8 GB RAM | 128 GB ROM</li>,
#  <li class="DTBslk">17.17 cm (6.76 inch) Display</li>,
#  <li class="DTBslk">50MP + 2MP | 32MP Front Camera</li>,
#  <li class="DTBslk">7200 mAh Li-ion Battery</li>,
#  <li class="DTBslk">Dimensity 7400-Turbo Processor</li>,
#  <li class="DTBslk">1 Year Manufacturer Warranty for Device and 6 Months Manufacturer Warranty for Inbox Accessories</li>]

# %%
for i in mobile.find_all('li',class_="DTBslk"):
  print(i.text)
# Out:
# 8 GB RAM | 128 GB ROM
# 17.17 cm (6.76 inch) Display
# 50MP + 2MP | 32MP Front Camera
# 7200 mAh Li-ion Battery
# Dimensity 7400-Turbo Processor
# 1 Year Manufacturer Warranty for Device and 6 Months Manufacturer Warranty for Inbox Accessories
